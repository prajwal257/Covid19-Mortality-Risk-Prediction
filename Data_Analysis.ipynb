# %%
import numpy as np
import pandas as pd

# %%
with open('Data_Set.csv') as file:
    print(file)
# Out:
# <_io.TextIOWrapper name='Data_Set.csv' mode='r' encoding='cp1252'>

# %%
dataset = pd.read_csv('Data_Set.csv', encoding = 'cp1252')

# %%
dataset.head(10)
# Out:
#   ï»¿survey_date region country  ip_latitude  ip_longitude  ip_accuracy  \
# 0     25-03-2020    NaN      US      33.9031     -118.1494          500
# 1     26-03-2020     EU      NL      52.0218        4.5357            5
# 2     28-03-2020     SA      BR     -26.8740      -48.7028           10
# 3     27-03-2020     EU      CH      47.1921        8.1766           20
# 4     27-03-2020    NaN      US      40.5733     -111.9107            5
# 5     31-03-2020     EU      ES      41.3691        2.1462           20
# 6     01-04-2020    NaN      US      39.9857      -75.0585            5
# 7     05-04-2020    NaN      US      42.3931      -71.2092            5
# 8     05-04-2020    NaN      US      38.7414      -77.1411          100
# 9     04-04-2020    NaN      US      42.0564      -71.2342            5
#
#       sex     age  height  weight  ...  heart_disease lung_disease diabetes  \
# 0    male   50_60     184      80  ...              0            0        0
# ...

# %%
dataset.columns
# Out:
# Index(['ï»¿survey_date', 'region', 'country', 'ip_latitude', 'ip_longitude',
#        'ip_accuracy', 'sex', 'age', 'height', 'weight', 'bmi', 'blood_type',
#        'insurance', 'income', 'race', 'immigrant', 'smoking', 'contacts_count',
#        'house_count', 'public_transport_count', 'working', 'worried',
#        'covid19_positive', 'covid19_symptoms', 'covid19_contact', 'asthma',
#        'kidney_disease', 'liver_disease', 'compromised_immune',
#        'heart_disease', 'lung_disease', 'diabetes', 'hiv_positive',
#        'hypertension', 'other_chronic', 'nursing_home', 'health_worker',
#        'risk_infection', 'risk_mortality'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (5111, 39)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5111 entries, 0 to 5110
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿survey_date          5111 non-null   object
#  1   region                  1485 non-null   object
#  2   country                 5109 non-null   object
#  3   sex                     5111 non-null   object
#  4   age                     5111 non-null   object
#  5   height                  5111 non-null   int64
#  6   weight                  5111 non-null   int64
#  7   bmi                     5111 non-null   float64
#  8   blood_type              5111 non-null   object
#  9   race                    3943 non-null   object
#  10  smoking                 5072 non-null   object
#  11  contacts_count          5065 non-null   float64
#  12  public_transport_count  3943 non-null   float64
#  13  working                 5065 non-null   object
# ...

# %% [markdown]
# Dealing with Nan and Errors

# %%
dataset = dataset.drop(columns=['ip_latitude', 'ip_longitude', 'ip_accuracy', 'insurance', 'income', 'immigrant', 'house_count'])

# %%
dataset.shape
# Out:
# (5111, 32)

# %%
dataset.isnull().sum()
# Out:
# ï»¿survey_date               0
# region                    3626
# country                      2
# sex                          0
# age                          0
# height                       0
# weight                       0
# bmi                          0
# blood_type                   0
# race                      1168
# smoking                     39
# contacts_count              46
# public_transport_count    1168
# working                     46
# worried                   1168
# covid19_positive             0
# covid19_symptoms             0
# covid19_contact              0
# asthma                       0
# kidney_disease               0
# liver_disease                0
# compromised_immune           0
# heart_disease                0
# lung_disease                 0
# diabetes                     0
# hiv_positive                 0
# hypertension                 0
# other_chronic                0
# nursing_home                 0
# health_worker                0
# ...

# %%
len(dataset['country'].unique())
# Out:
# 91

# %%
dataset['country'].unique()
# Out:
# array(['US', 'NL', 'BR', 'CH', 'ES', 'AU', 'RU', 'JP', 'MT', 'GB', 'NZ',
#        'PK', 'CL', 'IE', 'UA', 'CA', 'IN', 'BE', 'BH', 'HU', 'MX', 'GR',
#        'IT', 'DE', 'SG', 'HK', 'EG', 'RS', 'PE', 'FR', 'CO', 'PS', 'DO',
#        'SE', 'MK', 'PT', 'TH', 'RO', 'PH', 'LT', 'AR', 'DK', 'GE', 'EC',
#        'SA', 'PA', 'ZA', 'AM', 'TR', 'BD', 'DZ', 'QA', 'IQ', 'IL', 'ID',
#        'AE', 'GT', 'CZ', 'IR', 'KZ', 'BG', 'NO', nan, 'AT', 'MD', 'SK',
#        'HN', 'ET', 'SV', 'PL', 'MO', 'HR', 'BS', 'CR', 'SI', 'AD', 'LU',
#        'BA', 'KR', 'NP', 'MU', 'PR', 'FI', 'MZ', 'VI', 'MY', 'LV', 'AW',
#        'MM', 'KY', 'KE'], dtype=object)

# %%
import seaborn as sns
# %matplotlib inline

# %%
dataset.skew().sort_values(ascending=False)
# Out:
# C:\Users\Prajwal\AppData\Local\Temp/ipykernel_2340/681945877.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.skew().sort_values(ascending=False)
# hiv_positive              15.508909
# risk_mortality            13.180574
# nursing_home              10.401023
# liver_disease             10.175924
# age                       10.085116
# kidney_disease             7.964242
# lung_disease               6.159167
# public_transport_count     6.091561
# heart_disease              4.768362
# health_worker              3.653815
# compromised_immune         3.605102
# other_chronic              3.341092
# diabetes                   2.988074
# covid19_contact            2.369179
# covid19_symptoms           2.354682
# asthma                     2.284441
# bmi                        2.205616
# ...

# %%
sns.distplot(dataset['risk_mortality'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='risk_mortality', ylabel='Density'>

# %%
sns.distplot(dataset['hiv_positive'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='hiv_positive', ylabel='Density'>

# %%
sns.distplot(dataset['bmi'], hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(dataset['weight'], hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(dataset['height'], hist=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='height', ylabel='Density'>

# %%
dataset_from_US = dataset.loc[dataset['country']=="US"]

# %%
dataset_from_US = dataset_from_US.loc[dataset_from_US['covid19_positive']==1]

# %%
dataset_from_US
# Out:
#      ï»¿survey_date region country     sex    age  height  weight   bmi  \
# 0        25-03-2020    NaN      US    male  50_60     184      80  23.6
# 4        27-03-2020    NaN      US    male  30_40     184     118  34.8
# 6        01-04-2020    NaN      US    male  40_50     174      84  27.7
# 7        05-04-2020    NaN      US  female  30_40     160      54  21.0
# 8        05-04-2020    NaN      US    male  20_30     180      84  25.9
# ...             ...    ...     ...     ...    ...     ...     ...   ...
# 1860     05-07-2020    NaN      US  female  70_80     160      82  32.0
# 1862     05-07-2020    NaN      US    male  60_70     196     100  26.0
# 1863     05-07-2020    NaN      US    male  60_70     180     104  32.0
# 1867     05-07-2020    NaN      US    male  30_40     192      84  22.7
# 1869     06-07-2020    NaN      US    male  40_50     174      76  25.1
#
#      blood_type      race  ... heart_disease  lung_disease  diabetes  \
# ...

# %%
#Taking the average of the dataset above.
dataset_from_US.describe()
# Out:
#             height       weight          bmi  contacts_count  \
# count  1222.000000  1222.000000  1222.000000     1198.000000
# mean    170.859247    90.510638    30.890917        8.398164
# std      11.405912    27.409734     8.814581        7.495979
# min     114.000000    44.000000    11.900000        0.000000
# 25%     164.000000    70.000000    24.500000        2.000000
# 50%     170.000000    86.000000    28.900000        5.000000
# 75%     178.000000   104.000000    35.800000       15.000000
# max     238.000000   180.000000    86.500000       21.000000
#
#        public_transport_count     worried  covid19_positive  covid19_symptoms  \
# count              354.000000  354.000000            1222.0       1222.000000
# mean                 0.406780    3.375706               1.0          0.310966
# std                  1.691023    0.769517               0.0          0.463078
# min                  0.000000    1.000000               1.0          0.000000
# ...

# %%
dataset_not_from_US = dataset.loc[dataset['country']!="US"]
dataset_not_from_US = dataset_not_from_US.loc[dataset_not_from_US['covid19_positive']==1]
dataset_not_from_US.describe()
# Out:
#            height      weight         bmi  contacts_count  \
# count  648.000000  648.000000  648.000000      626.000000
# mean   170.382716   82.632716   28.554938        8.408946
# std     11.703253   23.882006    9.364308        7.145495
# min    110.000000   44.000000   15.000000        0.000000
# 25%    164.000000   66.000000   23.300000        3.000000
# 50%    170.000000   80.000000   26.250000        5.000000
# 75%    178.000000   94.000000   31.200000       13.000000
# max    198.000000  180.000000  125.000000       21.000000
#
#        public_transport_count     worried  covid19_positive  covid19_symptoms  \
# count              355.000000  355.000000             648.0        648.000000
# mean                 0.791549    3.490141               1.0          0.285494
# std                  2.423155    0.782426               0.0          0.451998
# min                  0.000000    2.000000               1.0          0.000000
# ...

# %%
# Grouping the data according to country.
dataset_groupedby_country = dataset.groupby(by='country', dropna=True).mean()

# %%
dataset_groupedby_country.sort_values(by='risk_mortality', ascending=False)
# Out:
#              height     weight        bmi  contacts_count  \
# country
# IT       169.733333  84.533333  29.515556        6.622222
# AD       174.000000  70.000000  23.100000        1.000000
# PT       170.166667  84.500000  28.841667        6.750000
# AM       174.000000  94.000000  31.000000        1.000000
# NZ       174.222222  90.666667  29.144444       10.285714
# ...             ...        ...        ...             ...
# MZ       172.000000  62.000000  20.900000        4.000000
# QA       175.333333  82.666667  26.566667        6.000000
# BH       181.000000  74.000000  22.150000        5.500000
# FI       181.333333  94.000000  28.600000        5.666667
# KE       164.000000  66.000000  24.500000        4.000000
#
#          public_transport_count   worried  covid19_positive  covid19_symptoms  \
# country
# IT                     0.285714  3.047619          0.711111          0.333333
# AD                     0.000000  4.000000          0.000000          0.000000
# ...

# %%
# Grouping the data according to country.
dataset_groupedby_country = dataset.groupby(by='country', dropna=True).count()
dataset_groupedby_country.loc[dataset_groupedby_country['covid19_positive']==1]
dataset_groupedby_country.sort_values(by='bmi', ).head(20)
dataset_groupedby_country.loc[dataset_groupedby_country['ï»¿survey_date']>=10]
# Out:
#          ï»¿survey_date  region   sex   age  height  weight   bmi  blood_type  \
# country
# AE                   10      10    10    10      10      10    10          10
# AR                   63      63    63    63      63      63    63          63
# AU                   67      67    67    67      67      67    67          67
# BE                   21      21    21    21      21      21    21          21
# BR                  242     242   242   242     242     242   242         242
# CA                  189       0   189   189     189     189   189         189
# CH                   13      13    13    13      13      13    13          13
# CL                   14      14    14    14      14      14    14          14
# CO                   22      22    22    22      22      22    22          22
# DE                   36      36    36    36      36      36    36          36
# ES                   47      47    47    47      47      47    47          47
# ...

# %%
dataset_groupedby_country.sort_values(by='risk_mortality', ascending=False).head(5)
# Out:
#          ï»¿survey_date  region   sex   age  height  weight   bmi  blood_type  \
# country
# US                 3313       0  3313  3313    3313    3313  3313        3313
# GB                  347     347   347   347     347     347   347         347
# BR                  242     242   242   242     242     242   242         242
# CA                  189       0   189   189     189     189   189         189
# MX                   86       0    86    86      86      86    86          86
#
#          race  smoking  ...  heart_disease  lung_disease  diabetes  \
# country                 ...
# US       2439     3291  ...           3313          3313      3313
# GB        292      347  ...            347           347       347
# BR        140      242  ...            242           242       242
# CA        156      187  ...            189           189       189
# MX         80       86  ...             86            86        86
#
# ...

# %%
#Finding the relation between covid postive and risk infection.
sns.scatterplot(x=dataset_groupedby_country['covid19_positive'][:10], y=dataset_groupedby_country['risk_infection'][:10])
# Out:
# <AxesSubplot:xlabel='covid19_positive', ylabel='risk_infection'>

# %%
# Grouping the data according to country.
dataset_groupedby_country = dataset.groupby(by='country', dropna=True).count()
dataset_groupedby_country.sort_values(by='risk_mortality', ascending=False)
dataset_relation_between_risk_and_country = dataset_groupedby_country['risk_infection']

# %%
# Grouping the data according to country.
dataset_groupedby_country = dataset.groupby(by='country', dropna=True).mean()
dataset_groupedby_country.sort_values(by='risk_mortality', ascending=False)
dataset_relation_between_risk_and_country = dataset_groupedby_country['risk_infection']
dataset_relation_between_risk_and_country
# Out:
# country
# AD      6.000000
# AE     24.800000
# AM    100.000000
# AR     18.031746
# AT     25.600000
#          ...
# TR     52.750000
# UA    100.000000
# US     44.091760
# VI      5.000000
# ZA     37.406250
# Name: risk_infection, Length: 90, dtype: float64

# %%
plt.figure(figsize=(32,18))
plt.plot(dataset_relation_between_risk_and_country, label=['Country', 'risk_infection'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2340/260334839.py in <module>
# ----> 1 plt.figure(figsize=(32,18))
#       2 plt.plot(dataset_relation_between_risk_and_country, label=['Country', 'risk_infection'])
#
# NameError: name 'plt' is not defined

# %%
import face_recognition as fr
